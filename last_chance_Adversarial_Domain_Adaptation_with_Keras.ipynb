# %% [markdown]
# <a href="https://colab.research.google.com/github/Shellyga/Adversarial-Domain-Adaptation-with-Keras/blob/master/last_chance_Adversarial_Domain_Adaptation_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model

# %%
import random
import numpy as np
from keras.models import Model
from keras.applications.resnet50 import ResNet50
from keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense
from keras.layers import BatchNormalization, Activation, Dropout
# from keras_vggface.vggface import VGGFace
# from sklearn.preprocessing import LabelEncoder
# from sklearn.model_selection import train_test_split

def build_embedding(param, inp):
    network = eval(param["network_name"])
    base = network(weights = 'imagenet', include_top = False)
    feat = base(inp)
    flat = Flatten()(feat)
    return flat

def build_classifier(param, embedding):
    dense1 = Dense(400, name = 'class_dense1')(embedding)
    bn1 = BatchNormalization(name = 'class_bn1')(dense1)
    act1 = Activation('relu', name = 'class_act1')(bn1)
    drop2 = Dropout(param["drop_classifier"], name = 'class_drop1')(act1)

    dense2 = Dense(100, name = 'class_dense2')(drop2)
    bn2 = BatchNormalization(name = 'class_bn2')(dense2)
    act2 = Activation('relu', name = 'class_act2')(bn2)
    drop2 = Dropout(param["drop_classifier"], name = 'class_drop2')(act2)

    densel = Dense(param["source_label"].shape[1], name = 'class_dense_last')(drop2)
    bnl = BatchNormalization(name = 'class_bn_last')(densel)
    actl = Activation('softmax', name = 'class_act_last')(bnl)
    return actl

def build_discriminator(param, embedding):
    dense1 = Dense(400, name = 'dis_dense1')(embedding)
    bn1 = BatchNormalization(name='dis_bn1')(dense1)
    act1 = Activation('relu', name = 'dis_act1')(bn1)
    drop1 = Dropout(param["drop_discriminator"], name = 'dis_drop1')(act1)

    dense2 = Dense(100, name = 'dis_dense2')(drop1)
    bn2 = BatchNormalization(name='dis_bn2')(dense2)
    act2 = Activation('relu', name = 'dis_act2')(bn2)
    drop2 = Dropout(param["drop_discriminator"], name = 'dis_drop2')(act2)

    densel = Dense(1, name = 'dis_dense_last')(drop2)
    bnl = BatchNormalization(name = 'dis_bn_last')(densel)
    actl = Activation('sigmoid', name = 'dis_act_last')(bnl)
    return actl

def build_combined_classifier(inp, classifier):
    comb_model = Model(inputs = inp, outputs = [classifier])
    return comb_model

def build_combined_discriminator(inp, discriminator):
    comb_model = Model(inputs = inp, outputs = [discriminator])
    return comb_model

def build_combined_model(inp, comb):
    comb_model = Model(inputs = inp, outputs = comb)
    return comb_model
# Out:
# Using TensorFlow backend.

# %%
pip install keras_vggface

# %% [markdown]
# # Optimizer

# %%
import numpy as np
from keras.optimizers import Adam

def opt_classifier(param):
    return Adam(lr=param["lr_classifier"], beta_1=param["b1_classifier"], beta_2=param["b2_classifier"])

def opt_discriminator(param):
    return Adam(lr=param["lr_discriminator"], beta_1=param["b1_discriminator"], beta_2=param["b2_discriminator"])

def opt_combined(param):
    return Adam(lr=param["lr_combined"], beta_1=param["b1_combined"], beta_2=param["b2_combined"])

# %% [markdown]
# # Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def aug_training_set_loader(images,labels,inp_dims):
    NUM_COPIES = ceil(300/len(images))
    images = np.array(images)
    images=augment(inp_dims[0], inp_dims[1], images, NUM_COPIES)
    aug_labels =[]
    for x in labels:
        for i in range(NUM_COPIES+1):  # NUM_COPIES+1-> numbers of augmentations + 1 original
            aug_labels.append(x)
    images, labels = skshuffle(images, aug_labels)
    images = np.array(images)
    labels = np.array(labels)
    return images, labels
    
# def data_loader(filepath, inp_dims):
#     # Load images and corresponding labels from the text file, stack them in numpy arrays and return
#     if not os.path.isfile(filepath):
#         print("File path {} does not exist. Exiting...".format(filepath))
#         # sys.exit() 
#     img = []
#     label = []
#     detector = dlib.get_frontal_face_detector()
#     predictor = "drive/My Drive/project_data/shape_predictor_5_face_landmarks.dat"
#     with open(filepath,'r',encoding='utf-8-sig') as fp:
#         for line in fp:
#           token = line.split()
#           image_path = "drive/My Drive/project_data/"+token[0]
#           i = pil_loader(image_path)
#           i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
#           frame_1 = align_and_crop(detector, np.array(i), predictor)[0]
#           frame_1 = cv2.resize(frame_1,(inp_dims[0], inp_dims[1])).flatten()
#           img.append(frame_1)
#           label.append(int(token[1]))
#     img = np.array(img)
#     label = np.array(label)
#     # X, X_test, y, y_test = train_test_split(img, label, test_size=0.25, random_state=42)
#     # X, X_test, y, y_test = np.array(X), np.array(X_test), np.array(y), np.array(y_test)
#     # return X, X_test, y, y_test
#     return img,label

# def one_hot_encoding(s_label,t_label):
#     # Read the source and target labels from param
#     # Encode the labels into one-hot format
#     classes = (np.concatenate((s_label, t_label), axis = 0))
#     num_classes = np.max(classes)
#     if 0 in classes:
#             num_classes = num_classes+1
#     s_label = to_categorical(s_label, num_classes = num_classes)
#     t_label = to_categorical(t_label, num_classes = num_classes)
#     return s_label, t_label

# %%
SEED = 7
import os
import sys
import argparse
import random
import numpy as np
# import tensorflow.python.keras as tf
from tensorflow.compat.v1 import set_random_seed
# import tensorflow.python.keras as tf
from sklearn.model_selection import train_test_split
from sklearn import metrics
from plotnine import *
import pandas as pd

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from math import ceil
from sklearn.utils import shuffle as skshuffle

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
set_random_seed(SEED)
random.seed(SEED)

from PIL import Image
from keras.utils import to_categorical
from keras.layers import Input
from keras.optimizers import Adam
from keras.utils import multi_gpu_model
from sklearn.metrics import accuracy_score


def pil_loader(path):
    # print(path)
    # Return the RGB variant of input image
    with open(path, 'rb') as f:
      with Image.open(f) as img:
        return img.convert('RGB')

def one_hot_encoding(param):
    # Read the source and target labels from param
    s_label = param["source_label"]
    t_label = param["target_label"]

    # Encode the labels into one-hot format
    classes = (np.concatenate((s_label, t_label), axis = 0))
    num_classes = np.max(classes)
    if 0 in classes:
            num_classes = num_classes+1
    s_label = to_categorical(s_label, num_classes = num_classes)
    t_label = to_categorical(t_label, num_classes = num_classes)
    return s_label, t_label
            
def data_loader(filepath, inp_dims):
    # Load images and corresponding labels from the text file, stack them in numpy arrays and return
    if not os.path.isfile(filepath):
        print("File path {} does not exist. Exiting...".format(filepath))
        # sys.exit() 
    img = []
    label = []
    with open(filepath,'r',encoding='utf-8-sig') as fp:
        for line in fp:
            token = line.split()
            image_path = "drive/My Drive/project_data/"+token[0]
            i = pil_loader(image_path)
            i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
            detector = dlib.get_frontal_face_detector()
            predictor = "drive/My Drive/project_data/shape_predictor_5_face_landmarks.dat"
            frame_1 = align_and_crop(detector, np.array(i), predictor)[0]
            # frame_1 = cv2.resize(frame_1,(inp_dims[0], inp_dims[1])).flatten()
            frame_1 = cv2.resize(frame_1,(inp_dims[0], inp_dims[1]))
            img.append(frame_1)
            label.append(int(token[1]))
    # NUM_COPIES = ceil(300/len(img))
    # img = np.array(img)
    # img=augment(inp_dims[0], inp_dims[1], img, NUM_COPIES)
    # aug_labels =[]
    # for x in label:
    #     for i in range(NUM_COPIES+1):  # NUM_COPIES+1-> numbers of augmentations + 1 original
    #         aug_labels.append(x)
    # img, label = skshuffle(img, aug_labels)
    img, label = skshuffle(img, label)
    img = np.array(img)
    label = np.array(label)
    return img, label
    
# def data_loader(filepath, inp_dims):
#     # Load images and corresponding labels from the text file, stack them in numpy arrays and return
#     if not os.path.isfile(filepath):
#         print("File path {} does not exist. Exiting...".format(filepath))
#         # sys.exit() 
#     img = []
#     label = []
#     with open(filepath,'r',encoding='utf-8-sig') as fp:
#         for line in fp:
#             token = line.split()
#             # print('drive/My Drive/project_data/'+token[0])
#             image_path = "drive/My Drive/project_data/"+token[0]
#             i = pil_loader(image_path)
#             i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
#             img.append(np.array(i))
#             label.append(int(token[1]))
#     img = np.array(img)
#     label = np.array(label)
#     return img, label

def batch_generator(data, batch_size):
    #Generate batches of data.
    all_examples_indices = len(data[0])
    while True:
        mini_batch_indices = np.random.choice(all_examples_indices, size = batch_size, replace = False)
        tbr = [k[mini_batch_indices] for k in data]
        yield tbr



def train(param):
    models = {}
    inp = Input(shape = (param["inp_dims"]))
    embedding = build_embedding(param, inp)
    classifier = build_classifier(param, embedding)
    discriminator = build_discriminator(param, embedding)

    if param["number_of_gpus"] > 1:
        models["combined_classifier"] = multi_gpu_model(build_combined_classifier(inp, classifier), gpus = param["number_of_gpus"])
        models["combined_discriminator"] = multi_gpu_model(build_combined_discriminator(inp, discriminator), gpus = param["number_of_gpus"])
        models["combined_model"] = multi_gpu_model(build_combined_model(inp, [classifier, discriminator]), gpus = param["number_of_gpus"])
    else:
        models["combined_classifier"] = build_combined_classifier(inp, classifier)
        models["combined_discriminator"] = build_combined_discriminator(inp, discriminator)
        models["combined_model"] = build_combined_model(inp, [classifier, discriminator])

    models["combined_classifier"].compile(optimizer = opt_classifier(param), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    models["combined_discriminator"].compile(optimizer = opt_discriminator(param), loss = 'binary_crossentropy', metrics = ['accuracy'])
    models["combined_model"].compile(optimizer = opt_combined(param), loss = {'class_act_last': 'categorical_crossentropy', 'dis_act_last': \
        'binary_crossentropy'}, loss_weights = {'class_act_last': param["class_loss_weight"], 'dis_act_last': param["dis_loss_weight"]}, metrics = ['accuracy'])

    Xs, ys = param["source_data"], param["source_label"]
    Xt, yt = param["target_data"], param["target_label"]

    Xt, Xt_test, yt, yt_test = train_test_split(Xt, yt, test_size=0.25, random_state=42)
    Xs, Xs_test, ys, ys_test = train_test_split(Xs, ys, test_size=0.25, random_state=42)
    
    # Xs_test, ys_test = param["source_data_test"], param["source_label_test"]
    # Xt_test, yt_test = param["target_data_test"], param["target_label_test"]
    Xs, ys = aug_training_set_loader(Xs, ys, param["inp_dims"])
    Xt, yt = aug_training_set_loader(Xt, yt, param["inp_dims"])

    # Source domain is represented by label 0 and Target by 1
    ys_adv = np.array(([0.] * ys.shape[0]))
    yt_adv = np.array(([1.] * yt.shape[0]))

    y_advb_1 = np.array(([1] * param["batch_size"] + [0] * param["batch_size"])) # For gradient reversal
    y_advb_2 = np.array(([0] * param["batch_size"] + [1] * param["batch_size"]))
    weight_class = np.array(([1] * param["batch_size"] + [0] * param["batch_size"]))
    weight_adv = np.ones((param["batch_size"] * 2,))
    S_batches = batch_generator([Xs, ys], param["batch_size"])
    T_batches = batch_generator([Xt, np.zeros(shape = (len(Xt),))], param["batch_size"])

    param["target_accuracy"] = 0

    # optim = {}
    # optim["iter"] = 0
    # optim["acc"] = ""
    # optim["labels"] = np.array(Xt.shape[0],)
    # gap_last_snap = 0

    acc_source=[]
    acc_target=[]
    acc_domain_source=[]
    acc_domain_target=[]
    loss_discriminator = []
    loss_classifier_source=[]

    for i in range(param["num_iterations"]):        
        Xsb, ysb = next(S_batches)
        Xtb, ytb = next(T_batches)
        X_adv = np.concatenate([Xsb, Xtb])
        y_class = np.concatenate([ysb, np.zeros_like(ysb)])

        adv_weights = []
        for layer in models["combined_model"].layers:
            if (layer.name.startswith("dis_")):
                adv_weights.append(layer.get_weights())
          
        stats1 = models["combined_model"].train_on_batch(X_adv, [y_class, y_advb_1],\
                                sample_weight=[weight_class, weight_adv])            
        k = 0
        for layer in models["combined_model"].layers:
            if (layer.name.startswith("dis_")):                    
                layer.set_weights(adv_weights[k])
                k += 1

        class_weights = []        
        for layer in models["combined_model"].layers:
            if (not layer.name.startswith("dis_")):
                class_weights.append(layer.get_weights())  

        stats2 = models["combined_discriminator"].train_on_batch(X_adv, [y_advb_2])

        k = 0
        for layer in models["combined_model"].layers:
            if (not layer.name.startswith("dis_")):
                layer.set_weights(class_weights[k])
                k += 1

        if ((i + 1) % param["test_interval"] == 0):
            ys_pred = models["combined_classifier"].predict(Xs)
            yt_pred = models["combined_classifier"].predict(Xt)
            
            ys_adv_pred = models["combined_discriminator"].predict(Xs)
            yt_adv_pred = models["combined_discriminator"].predict(Xt)

            source_accuracy = accuracy_score(ys.argmax(1), ys_pred.argmax(1))              
            target_accuracy = accuracy_score(yt.argmax(1), yt_pred.argmax(1))
            source_domain_accuracy = accuracy_score(ys_adv, np.round(ys_adv_pred))              
            target_domain_accuracy = accuracy_score(yt_adv, np.round(yt_adv_pred))

            acc_source.append(source_accuracy)
            acc_target.append(target_accuracy)
            acc_domain_source.append(source_domain_accuracy)
            acc_domain_target.append(target_domain_accuracy)

            loss_discriminator.append(stats2)
            loss_classifier_source.append(stats1)

            log_str = "iter: {:05d}: \nLABEL CLASSIFICATION: source_accuracy: {:.5f}, target_accuracy: {:.5f}\
                    \nDOMAIN DISCRIMINATION: source_domain_accuracy: {:.5f}, target_domain_accuracy: {:.5f} \n"\
                                                         .format(i, source_accuracy*100, target_accuracy*100,
                                                      source_domain_accuracy*100, target_domain_accuracy*100)
            print(log_str)

            # if param["target_accuracy"] < target_accuracy:              
            #     optim["iter"] = i
            #     optim["acc"] = log_str
            #     optim["labels"] = ys_pred.argmax(1)

                # if (gap_last_snap >= param["snapshot_interval"]):
                #     gap_last_snap = 0
                #     np.save(os.path.join(param["output_path"],"yPred_{}".format(optim["iter"])), optim["labels"])
                #     open(os.path.join(param["output_path"], "acc_{}.txt".format(optim["iter"])), "w").write(optim["acc"])
                #     models["combined_classifier"].save(os.path.join(param["output_path"],"iter_{:05d}_model.h5".format(i)))
        # gap_last_snap = gap_last_snap + 1;

    print("Source matrix: ",metrics.confusion_matrix(ys.argmax(1), ys_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt.argmax(1), yt_pred.argmax(1)))

    ys_test_pred = models["combined_classifier"].predict(Xs_test)
    yt_test_pred = models["combined_classifier"].predict(Xt_test)
    source_accuracy_test = accuracy_score(ys_test.argmax(1), ys_test_pred.argmax(1))              
    target_accuracy_test = accuracy_score(yt_test.argmax(1), yt_test_pred.argmax(1))

    print("source accuracy test",source_accuracy_test)
    print("target accuracy test",target_accuracy_test)

    print("Source matrix: ",metrics.confusion_matrix(ys_test.argmax(1), ys_test_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt_test.argmax(1), yt_test_pred.argmax(1)))

    # ys_test_adv_pred = models["combined_discriminator"].predict(Xs_test)
    # yt_test_adv_pred = models["combined_discriminator"].predict(Xt_test)
    # domain_source_accuracy_test = accuracy_score(ys_adv, np.round(ys_test_adv_pred))              
    # domain_target_accuracy_test = accuracy_score(yt_adv, np.round(yt_test_adv_pred))

    # print("discriminator source accuracy test",domain_source_accuracy_test)
    # print("discriminator target accuracy test",domain_target_accuracy_test)

    # print(param["num_iterations"]/ (param["test_interval"]-1))
    N = np.arange(0,len(acc_source))

    plt.style.use("ggplot")
    plt.figure()
    plt.plot(N, np.array(acc_source), label="Source accuracy")
    plt.plot(N, np.array(acc_target), label="Target accuracy")
    plt.plot(N, np.array(acc_domain_source), label="Domain Source accuracy")
    plt.plot(N, np.array(acc_domain_target), label="Domain Target accuracy")
    plt.title("Training Accuracy of Source and Target ")
    plt.xlabel("Number of intervals")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

    plt.style.use("ggplot")
    plt.figure()
    plt.plot(N, np.array(loss_classifier_source), label="Classifier Loss")
    plt.plot(N, np.array(loss_discriminator), label="Discriminator loss")
    plt.title("Training Loss of Source and Target ")
    plt.xlabel("Number of intervals")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %% [markdown]
# # Main

# %%
if __name__ == "__main__":
    # Read parameter values from the console
    parser = argparse.ArgumentParser(description = 'Domain Adaptation')
    parser.add_argument('--number_of_gpus', type = int, nargs = '?', default = '1', help = "Number of gpus to run")
    parser.add_argument('--network_name', type = str, default = 'ResNet50', help = "Name of the feature extractor network")
    parser.add_argument('--dataset_name', type = str, default = 'Office', help = "Name of the source dataset")
    parser.add_argument('--dropout_classifier', type = float, default = 0.25, help = "Dropout ratio for classifier")
    parser.add_argument('--dropout_discriminator', type = float, default = 0.25, help = "Dropout ratio for discriminator")    
    parser.add_argument('--source_path', type = str, default = 'amazon_10_list.txt', help = "Path to source dataset")
    parser.add_argument('--target_path', type = str, default = 'webcam_10_list.txt', help = "Path to target dataset")
    parser.add_argument('--lr_classifier', type = float, default = 0.0001, help = "Learning rate for classifier model")
    parser.add_argument('--b1_classifier', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for classifier model optimizer")
    parser.add_argument('--b2_classifier', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for classifier model optimizer")
    parser.add_argument('--lr_discriminator', type = float, default = 0.00001, help = "Learning rate for discriminator model")
    parser.add_argument('--b1_discriminator', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for discriminator model optimizer")
    parser.add_argument('--b2_discriminator', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for discriminator model optimizer")
    parser.add_argument('--lr_combined', type = float, default = 0.00001, help = "Learning rate for combined model")
    parser.add_argument('--b1_combined', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for combined model optimizer")
    parser.add_argument('--b2_combined', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for combined model optimizer")
    parser.add_argument('--classifier_loss_weight', type = float, default = 1, help = "Classifier loss weight")
    parser.add_argument('--discriminator_loss_weight', type = float, default = 4, help = "Discriminator loss weight")
    parser.add_argument('--batch_size', type = int, default = 32, help = "Batch size for training")
    parser.add_argument('--test_interval', type = int, default = 3, help = "Gap between two successive test phases")
    parser.add_argument('--num_iterations', type = int, default = 120, help = "Number of iterations")
    parser.add_argument('--snapshot_interval', type = int, default = 500, help = "Minimum gap between saving outputs")
    parser.add_argument('--output_dir', type = str, default = 'Models', help = "Directory for saving outputs")
    # args = parser.parse_args()

    # Set GPU device
    # os.environ["CUDA_VISIBLE_DEVICES"] = str(list(np.arange(args.number_of_gpus))).strip('[]')

    # Initialize parameters
    param = {}
    param["number_of_gpus"] = 1
    param["network_name"] = 'ResNet50'
    param["inp_dims"] = [224, 224, 3]
    param["num_iterations"] = 10000
    # param["num_iterations"] = 500
    param["lr_classifier"] = 0.0001
    param["b1_classifier"] = 0.9
    param["b2_classifier"] = 0.999    
    param["lr_discriminator"] = 0.00001
    param["b1_discriminator"] =  0.9
    param["b2_discriminator"] = 0.999
    param["lr_combined"] = 0.00001
    param["b1_combined"] =  0.9
    param["b2_combined"] =  0.999       
    # param["batch_size"] = int(32)
    param["batch_size"] = int(32/2)
    param["class_loss_weight"] = 1
    param["dis_loss_weight"] = 4    
    param["drop_classifier"] = 0.25
    param["drop_discriminator"] = 0.25
    param["test_interval"] = 100
    param["source_path"] = 'drive/My Drive/project_data/your_file.txt'
    param["target_path"] = 'drive/My Drive/project_data/your_file_shelly.txt' 
    # param["snapshot_interval"] = 500
    param["snapshot_interval"] = 5
    param["output_path"] = 'drive/My Drive/project_data/result2'

    # Create directory for saving models and log files
    if not os.path.exists(param["output_path"]):
        os.mkdir(param["output_path"])
    
    # Load source and target data
    param["source_data"], param["source_label"] = data_loader(param["source_path"], param["inp_dims"])
    param["target_data"], param["target_label"] = data_loader(param["target_path"], param["inp_dims"])

    # Encode labels into one-hot format
    param["source_label"], param["target_label"] = one_hot_encoding(param)

    # Xt, Xt_test, yt, yt_test = data_loader(param["target_path"], param["inp_dims"])
    # Xs, Xs_test, ys, ys_test = data_loader(param["source_path"], param["inp_dims"])

    # param["target_data"], param["target_label"] = aug_training_set_loader(Xt,yt,param["inp_dims"])
    # param["source_data"], param["source_label"] = aug_training_set_loader(Xs,ys,param["inp_dims"])

    # param["target_data_test"], param["target_label_test"] = Xt_test,yt_test
    # param["source_data_test"], param["source_label_test"] = Xs_test,ys_test

    # # Encode labels into one-hot format
    # param["source_label"], param["target_label"] = one_hot_encoding(param["source_label"], param["target_label"])
    # param["source_label_test"], param["target_label_test"] = one_hot_encoding(param["source_label_test"], param["target_label_test"])


    # Train data
    train(param)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step
# iter: 00099:
# LABEL CLASSIFICATION: source_accuracy: 98.88889, target_accuracy: 58.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.77778, target_domain_accuracy: 99.11111
#
# iter: 00199:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 66.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00299:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 67.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00399:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 67.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00499:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 69.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00599:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 69.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00699:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 70.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 100.00000
#
# iter: 00799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 68.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 97.77778
#
# iter: 00899:
# LABEL CLASSIFICATION: source_accuracy: 97.55556, target_accuracy: 64.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 92.00000
#
# iter: 00999:
# LABEL CLASSIFICATION: source_accuracy: 93.55556, target_accuracy: 68.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 91.77778, target_domain_accuracy: 98.00000
#
# iter: 01099:
# LABEL CLASSIFICATION: source_accuracy: 97.33333, target_accuracy: 58.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 96.44444, target_domain_accuracy: 86.44444
#
# iter: 01199:
# LABEL CLASSIFICATION: source_accuracy: 90.00000, target_accuracy: 60.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 99.11111, target_domain_accuracy: 67.77778
#
# iter: 01299:
# LABEL CLASSIFICATION: source_accuracy: 94.66667, target_accuracy: 55.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 97.55556, target_domain_accuracy: 70.44444
#
# iter: 01399:
# LABEL CLASSIFICATION: source_accuracy: 99.11111, target_accuracy: 60.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 65.33333, target_domain_accuracy: 98.00000
#
# iter: 01499:
# LABEL CLASSIFICATION: source_accuracy: 98.44444, target_accuracy: 60.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 83.33333, target_domain_accuracy: 83.33333
#
# iter: 01599:
# LABEL CLASSIFICATION: source_accuracy: 90.66667, target_accuracy: 51.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 70.22222, target_domain_accuracy: 85.11111
#
# iter: 01699:
# LABEL CLASSIFICATION: source_accuracy: 87.33333, target_accuracy: 48.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 51.33333, target_domain_accuracy: 70.00000
#
# iter: 01799:
# LABEL CLASSIFICATION: source_accuracy: 85.33333, target_accuracy: 47.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 31.33333, target_domain_accuracy: 80.00000
#
# iter: 01899:
# LABEL CLASSIFICATION: source_accuracy: 95.77778, target_accuracy: 53.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 86.66667, target_domain_accuracy: 64.88889
#
# iter: 01999:
# LABEL CLASSIFICATION: source_accuracy: 62.22222, target_accuracy: 60.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 44.66667, target_domain_accuracy: 61.33333
#
# iter: 02099:
# LABEL CLASSIFICATION: source_accuracy: 91.77778, target_accuracy: 47.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 36.44444, target_domain_accuracy: 54.44444
#
# iter: 02199:
# LABEL CLASSIFICATION: source_accuracy: 81.55556, target_accuracy: 53.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 46.22222, target_domain_accuracy: 45.33333
#
# iter: 02299:
# LABEL CLASSIFICATION: source_accuracy: 90.66667, target_accuracy: 62.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 4.00000, target_domain_accuracy: 87.55556
#
# iter: 02399:
# LABEL CLASSIFICATION: source_accuracy: 98.44444, target_accuracy: 58.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 66.22222, target_domain_accuracy: 34.00000
#
# iter: 02499:
# LABEL CLASSIFICATION: source_accuracy: 94.66667, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 87.33333, target_domain_accuracy: 36.22222
#
# iter: 02599:
# LABEL CLASSIFICATION: source_accuracy: 98.88889, target_accuracy: 57.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 24.22222, target_domain_accuracy: 78.88889
#
# iter: 02699:
# LABEL CLASSIFICATION: source_accuracy: 91.33333, target_accuracy: 56.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.77778, target_domain_accuracy: 20.00000
#
# iter: 02799:
# LABEL CLASSIFICATION: source_accuracy: 93.11111, target_accuracy: 61.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 80.00000, target_domain_accuracy: 20.00000
#
# iter: 02899:
# LABEL CLASSIFICATION: source_accuracy: 88.44444, target_accuracy: 70.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.55556, target_domain_accuracy: 24.66667
#
# iter: 02999:
# LABEL CLASSIFICATION: source_accuracy: 96.66667, target_accuracy: 59.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 78.44444, target_domain_accuracy: 19.77778
#
# iter: 03099:
# LABEL CLASSIFICATION: source_accuracy: 93.55556, target_accuracy: 60.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 96.44444, target_domain_accuracy: 2.00000
#
# iter: 03199:
# LABEL CLASSIFICATION: source_accuracy: 89.33333, target_accuracy: 67.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 76.22222, target_domain_accuracy: 22.44444
#
# iter: 03299:
# LABEL CLASSIFICATION: source_accuracy: 87.33333, target_accuracy: 65.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 78.22222, target_domain_accuracy: 20.22222
#
# iter: 03399:
# LABEL CLASSIFICATION: source_accuracy: 87.33333, target_accuracy: 58.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.55556, target_domain_accuracy: 19.77778
#
# iter: 03499:
# LABEL CLASSIFICATION: source_accuracy: 94.66667, target_accuracy: 52.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.11111, target_domain_accuracy: 18.88889
#
# iter: 03599:
# LABEL CLASSIFICATION: source_accuracy: 98.00000, target_accuracy: 52.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.33333, target_domain_accuracy: 18.22222
#
# iter: 03699:
# LABEL CLASSIFICATION: source_accuracy: 96.66667, target_accuracy: 52.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 80.22222, target_domain_accuracy: 18.00000
#
# iter: 03799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.33333, target_domain_accuracy: 5.55556
#
# iter: 03899:
# LABEL CLASSIFICATION: source_accuracy: 99.33333, target_accuracy: 56.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 79.11111, target_domain_accuracy: 19.33333
#
# iter: 03999:
# LABEL CLASSIFICATION: source_accuracy: 97.77778, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 76.00000, target_domain_accuracy: 18.00000
#
# iter: 04099:
# LABEL CLASSIFICATION: source_accuracy: 90.88889, target_accuracy: 60.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 74.00000, target_domain_accuracy: 36.44444
#
# iter: 04199:
# LABEL CLASSIFICATION: source_accuracy: 93.11111, target_accuracy: 46.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 28.88889, target_domain_accuracy: 67.33333
#
# iter: 04299:
# LABEL CLASSIFICATION: source_accuracy: 98.44444, target_accuracy: 42.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 23.11111, target_domain_accuracy: 63.77778
#
# iter: 04399:
# LABEL CLASSIFICATION: source_accuracy: 96.00000, target_accuracy: 57.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 40.88889, target_domain_accuracy: 33.55556
#
# iter: 04499:
# LABEL CLASSIFICATION: source_accuracy: 96.66667, target_accuracy: 50.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 66.44444, target_domain_accuracy: 29.77778
#
# iter: 04599:
# LABEL CLASSIFICATION: source_accuracy: 98.66667, target_accuracy: 58.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 56.22222, target_domain_accuracy: 35.77778
#
# iter: 04699:
# LABEL CLASSIFICATION: source_accuracy: 94.00000, target_accuracy: 52.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 69.11111, target_domain_accuracy: 25.11111
#
# iter: 04799:
# LABEL CLASSIFICATION: source_accuracy: 98.66667, target_accuracy: 55.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 59.55556, target_domain_accuracy: 12.44444
#
# iter: 04899:
# LABEL CLASSIFICATION: source_accuracy: 96.44444, target_accuracy: 60.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 63.33333, target_domain_accuracy: 35.55556
#
# iter: 04999:
# LABEL CLASSIFICATION: source_accuracy: 94.00000, target_accuracy: 55.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 4.44444, target_domain_accuracy: 44.22222
#
# iter: 05099:
# LABEL CLASSIFICATION: source_accuracy: 99.55556, target_accuracy: 46.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 5.77778, target_domain_accuracy: 89.55556
#
# iter: 05199:
# LABEL CLASSIFICATION: source_accuracy: 99.33333, target_accuracy: 56.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 74.44444, target_domain_accuracy: 19.77778
#
# iter: 05299:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 50.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 100.00000, target_domain_accuracy: 12.88889
#
# iter: 05399:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 65.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 9.11111, target_domain_accuracy: 55.77778
#
# iter: 05499:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 59.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 44.88889, target_domain_accuracy: 53.77778
#
# iter: 05599:
# LABEL CLASSIFICATION: source_accuracy: 99.55556, target_accuracy: 51.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 48.44444, target_domain_accuracy: 55.11111
#
# iter: 05699:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 40.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 20.88889, target_domain_accuracy: 64.88889
#
# iter: 05799:
# LABEL CLASSIFICATION: source_accuracy: 96.22222, target_accuracy: 64.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 19.77778, target_domain_accuracy: 41.11111
#
# iter: 05899:
# LABEL CLASSIFICATION: source_accuracy: 99.33333, target_accuracy: 42.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 27.11111, target_domain_accuracy: 67.77778
#
# iter: 05999:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 58.88889, target_domain_accuracy: 48.00000
#
# iter: 06099:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 52.22222, target_domain_accuracy: 24.88889
#
# iter: 06199:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 55.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 57.77778, target_domain_accuracy: 38.88889
#
# iter: 06299:
# LABEL CLASSIFICATION: source_accuracy: 98.88889, target_accuracy: 48.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 53.77778, target_domain_accuracy: 21.77778
#
# iter: 06399:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 58.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 27.33333, target_domain_accuracy: 71.77778
#
# iter: 06499:
# LABEL CLASSIFICATION: source_accuracy: 95.77778, target_accuracy: 47.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 61.11111, target_domain_accuracy: 52.00000
#
# iter: 06599:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 51.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 0.00000, target_domain_accuracy: 75.33333
#
# iter: 06699:
# LABEL CLASSIFICATION: source_accuracy: 99.33333, target_accuracy: 66.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 54.22222, target_domain_accuracy: 19.11111
#
# iter: 06799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 61.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 21.11111, target_domain_accuracy: 56.88889
#
# iter: 06899:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 44.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 54.88889, target_domain_accuracy: 14.22222
#
# iter: 06999:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 42.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 56.00000, target_domain_accuracy: 42.88889
#
# iter: 07099:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 44.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 45.33333, target_domain_accuracy: 50.44444
#
# iter: 07199:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 53.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 29.55556, target_domain_accuracy: 38.44444
#
# iter: 07299:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 45.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 26.00000, target_domain_accuracy: 60.00000
#
# iter: 07399:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 62.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 58.00000, target_domain_accuracy: 28.66667
#
# iter: 07499:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 23.33333, target_domain_accuracy: 69.33333
#
# iter: 07599:
# LABEL CLASSIFICATION: source_accuracy: 94.44444, target_accuracy: 68.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 35.55556, target_domain_accuracy: 22.88889
#
# iter: 07699:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 17.11111, target_domain_accuracy: 33.77778
#
# iter: 07799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 17.55556, target_domain_accuracy: 63.77778
#
# iter: 07899:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 51.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 36.22222, target_domain_accuracy: 38.00000
#
# iter: 07999:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 20.00000, target_domain_accuracy: 73.77778
#
# iter: 08099:
# LABEL CLASSIFICATION: source_accuracy: 99.55556, target_accuracy: 36.88889
# DOMAIN DISCRIMINATION: source_domain_accuracy: 45.33333, target_domain_accuracy: 54.00000
#
# iter: 08199:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 58.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 45.33333, target_domain_accuracy: 64.00000
#
# iter: 08299:
# LABEL CLASSIFICATION: source_accuracy: 99.33333, target_accuracy: 33.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 6.66667, target_domain_accuracy: 78.44444
#
# iter: 08399:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 43.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 29.55556, target_domain_accuracy: 45.33333
#
# iter: 08499:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 50.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 31.11111, target_domain_accuracy: 61.77778
#
# iter: 08599:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 45.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 3.11111, target_domain_accuracy: 62.00000
#
# iter: 08699:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 56.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 25.11111, target_domain_accuracy: 68.00000
#
# iter: 08799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 30.44444, target_domain_accuracy: 52.22222
#
# iter: 08899:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 64.22222
# DOMAIN DISCRIMINATION: source_domain_accuracy: 4.22222, target_domain_accuracy: 81.55556
#
# iter: 08999:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 56.88889, target_domain_accuracy: 30.66667
#
# iter: 09099:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 49.33333
# DOMAIN DISCRIMINATION: source_domain_accuracy: 55.33333, target_domain_accuracy: 14.88889
#
# iter: 09199:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 63.77778
# DOMAIN DISCRIMINATION: source_domain_accuracy: 40.88889, target_domain_accuracy: 59.33333
#
# iter: 09299:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 42.66667
# DOMAIN DISCRIMINATION: source_domain_accuracy: 20.66667, target_domain_accuracy: 38.44444
#
# iter: 09399:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 64.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 22.44444, target_domain_accuracy: 4.44444
#
# iter: 09499:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 48.44444
# DOMAIN DISCRIMINATION: source_domain_accuracy: 76.88889, target_domain_accuracy: 20.22222
#
# iter: 09599:
# LABEL CLASSIFICATION: source_accuracy: 99.77778, target_accuracy: 39.55556
# DOMAIN DISCRIMINATION: source_domain_accuracy: 59.11111, target_domain_accuracy: 3.77778
#
# iter: 09699:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 52.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 52.00000, target_domain_accuracy: 29.77778
#
# iter: 09799:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 37.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 59.11111, target_domain_accuracy: 1.55556
#
# iter: 09899:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 51.11111
# DOMAIN DISCRIMINATION: source_domain_accuracy: 57.33333, target_domain_accuracy: 22.44444
#
# iter: 09999:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 68.00000
# DOMAIN DISCRIMINATION: source_domain_accuracy: 38.22222, target_domain_accuracy: 72.22222
#
# Source matrix:  [[290   0]
#  [  0 160]]
# Target matrix:  [[ 12 118]
#  [ 26 294]]
# source accuracy test 0.8
# target accuracy test 0.5666666666666667
# Source matrix:  [[16  5]
#  [ 1  8]]
# Target matrix:  [[ 4  8]
#  [ 5 13]]

# %% [markdown]
# # Augment

# %%
from imgaug import augmenters as iaa
from imgaug import seed

def augment(width, height, data, NUM_COPIES):
    """
    preform augmentetion on the list of photos named 'data'
    :param width: width of a single photo
    :param height: height of a single photo
    :param data: a list of photos to augment
    :param NUM_COPIES: number of copies produced from the image
    :return: a list of photos that consists from the original photos and their augmentations
    """
    augmented_data = []
    sometimes = lambda aug: iaa.Sometimes(0.5, aug)
    seq = iaa.Sequential([
        sometimes(iaa.Sharpen(alpha=(0.0, 1.0), lightness=(0.75, 2.0))),
        sometimes(iaa.Fliplr()),  # horizontal flips
        sometimes(iaa.AddElementwise((-50, 50))),
        sometimes(iaa.Sometimes(0.5, iaa.GaussianBlur(sigma=(0.0, 2.0)))),
        sometimes(iaa.ContrastNormalization((0.8, 1.2))),
        sometimes(iaa.Multiply((0.8, 1.2), per_channel=0.2)),
        sometimes(iaa.Affine(
            scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            shear=(-8, 8)
        )),
        sometimes(iaa.Superpixels(p_replace=0.1, n_segments=150))
    ], random_order=True)  # apply augmenters in random order
    for img in data:
        copies = augment_image(width, height, img, seq, NUM_COPIES)
        copies.append(img.reshape(width, height, 3))
        for cpy in copies:
            augmented_data.append(cpy)
    return augmented_data


def augment_image(width, height, image, seq, NUM_COPIES):
    """
        augments a single image
    :param width: width of the image
    :param height: height of the image
    :param image: a matrix representing a rgb image
    :param seq: the augmantation sequence preformed
    :param NUM_COPIES: number of copies produced from the image
    :return: a list of all images made from 'image' not including the original
    """
    seed (1)
    copies = []
    image = image.reshape(width, height, 3)
    for i in range(NUM_COPIES):
        copies.append(seq.augment_image(image))

    return copies

# %% [markdown]
# # Crop

# %%
import dlib

import os
import sys
import cv2
import glob

# def resource_path(filename):
#     """ Get absolute path to resource, for the executable"""
#     if getattr(sys, 'frozen', False):
#         # The application is frozen
#         datadir = os.path.dirname(sys.executable)
#     else:
#         # The application is not frozen
#         # Change this bit to match where you store your data files:
#         datadir = os.path.dirname(__file__)

    # return os.path.join(datadir, filename)

def align_and_crop(detector, im_to_align, predictor_path):
    '''
    simply aligns the photo (using the detector to identify the eyes) and crops the face.
    :param im_to_align: an address of an image
    '''

    # a shape predictor to find face landmarks so we can precisely localize the face
    sp = dlib.shape_predictor(predictor_path)

    # Ask the detector to find the bounding boxes of each face. The 1 in the
    # second argument indicates that we should upsample the image 1 time.
    try:
        dets = detector(im_to_align, 1)
    except RuntimeError:
        return -1

    num_faces = len(dets)
    if num_faces == 0:
        return im_to_align, False

    # Find the 5 face landmarks we need to do the alignment.
    faces = dlib.full_object_detections()
    for detection in dets:
        faces.append(sp(im_to_align, detection))

    # get a single chip (aligned and cropped)
    image = dlib.get_face_chip(im_to_align, faces[0])
    # cv2.imshow("f", image) show image for testing
    return image, True

# %% [markdown]
# # Only Classifier

# %%
SEED = 7
import os
import sys
import argparse
import random
import numpy as np
# import tensorflow.python.keras as tf
from tensorflow.compat.v1 import set_random_seed
# import tensorflow.python.keras as tf
from sklearn.model_selection import train_test_split
from sklearn import metrics
from plotnine import *
import pandas as pd

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from math import ceil
from sklearn.utils import shuffle as skshuffle

os.environ['PYTHONHASHSEED']=str(SEED)
np.random.seed(SEED)
set_random_seed(SEED)
random.seed(SEED)

from PIL import Image
from keras.utils import to_categorical
from keras.layers import Input
from keras.optimizers import Adam
from keras.utils import multi_gpu_model
from sklearn.metrics import accuracy_score


def pil_loader(path):
    # print(path)
    # Return the RGB variant of input image
    with open(path, 'rb') as f:
      with Image.open(f) as img:
        return img.convert('RGB')

def one_hot_encoding(param):
    # Read the source and target labels from param
    s_label = param["source_label"]
    t_label = param["target_label"]

    # Encode the labels into one-hot format
    classes = (np.concatenate((s_label, t_label), axis = 0))
    num_classes = np.max(classes)
    if 0 in classes:
            num_classes = num_classes+1
    s_label = to_categorical(s_label, num_classes = num_classes)
    t_label = to_categorical(t_label, num_classes = num_classes)
    return s_label, t_label
            
# def data_loader(filepath, inp_dims):
#     # Load images and corresponding labels from the text file, stack them in numpy arrays and return
#     if not os.path.isfile(filepath):
#         print("File path {} does not exist. Exiting...".format(filepath))
#         # sys.exit() 
#     img = []
#     label = []
#     with open(filepath,'r',encoding='utf-8-sig') as fp:
#         for line in fp:
#             token = line.split()
#             image_path = "drive/My Drive/project_data/"+token[0]
#             i = pil_loader(image_path)
#             i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
#             detector = dlib.get_frontal_face_detector()
#             predictor = "drive/My Drive/project_data/shape_predictor_5_face_landmarks.dat"
#             frame_1 = align_and_crop(detector, np.array(i), predictor)[0]
#             frame_1 = cv2.resize(frame_1,(inp_dims[0], inp_dims[1])).flatten()
#             img.append(frame_1)
#             label.append(int(token[1]))
#     NUM_COPIES = ceil(300/len(img))
#     img = np.array(img)
#     img=augment(inp_dims[0], inp_dims[1], img, NUM_COPIES)
#     aug_labels =[]
#     for x in label:
#         for i in range(NUM_COPIES+1):  # NUM_COPIES+1-> numbers of augmentations + 1 original
#             aug_labels.append(x)
#     img, label = skshuffle(img, aug_labels)
#     img = np.array(img)
#     label = np.array(label)
#     return img, label
    
def data_loader(filepath, inp_dims):
    # Load images and corresponding labels from the text file, stack them in numpy arrays and return
    if not os.path.isfile(filepath):
        print("File path {} does not exist. Exiting...".format(filepath))
        # sys.exit() 
    img = []
    label = []
    with open(filepath,'r',encoding='utf-8-sig') as fp:
        for line in fp:
            token = line.split()
            # print('drive/My Drive/project_data/'+token[0])
            image_path = "drive/My Drive/project_data/"+token[0]
            i = pil_loader(image_path)
            i = i.resize((inp_dims[0], inp_dims[1]), Image.ANTIALIAS)
            img.append(np.array(i))
            label.append(int(token[1]))
    img = np.array(img)
    label = np.array(label)
    return img, label

def batch_generator(data, batch_size):
    #Generate batches of data.
    all_examples_indices = len(data[0])
    while True:
        mini_batch_indices = np.random.choice(all_examples_indices, size = batch_size, replace = False)
        tbr = [k[mini_batch_indices] for k in data]
        yield tbr



def train(param):
    models = {}
    inp = Input(shape = (param["inp_dims"]))
    embedding = build_embedding(param, inp)
    classifier = build_classifier(param, embedding)
    # discriminator = build_discriminator(param, embedding)

    if param["number_of_gpus"] > 1:
        models["combined_classifier"] = multi_gpu_model(build_combined_classifier(inp, classifier), gpus = param["number_of_gpus"])
        models["combined_discriminator"] = multi_gpu_model(build_combined_discriminator(inp, discriminator), gpus = param["number_of_gpus"])
        models["combined_model"] = multi_gpu_model(build_combined_model(inp, [classifier, discriminator]), gpus = param["number_of_gpus"])
    else:
        models["combined_classifier"] = build_combined_classifier(inp, classifier)
        # models["combined_discriminator"] = build_combined_discriminator(inp, discriminator)
        # models["combined_model"] = build_combined_model(inp, [classifier, discriminator])

    models["combined_classifier"].compile(optimizer = opt_classifier(param), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    # models["combined_discriminator"].compile(optimizer = opt_discriminator(param), loss = 'binary_crossentropy', metrics = ['accuracy'])
    # models["combined_model"].compile(optimizer = opt_combined(param), loss = {'class_act_last': 'categorical_crossentropy', 'dis_act_last': \
        # 'binary_crossentropy'}, loss_weights = {'class_act_last': param["class_loss_weight"], 'dis_act_last': param["dis_loss_weight"]}, metrics = ['accuracy'])

    Xs, ys = param["source_data"], param["source_label"]
    Xt, yt = param["target_data"], param["target_label"]

    Xt_train, Xt_test, yt_train, yt_test = train_test_split(Xt, yt, test_size=0.25, random_state=42)
    Xs_train, Xs_test, ys_train, ys_test = train_test_split(Xs, ys, test_size=0.25, random_state=42)


    # Source domain is represented by label 0 and Target by 1
    # ys_adv = np.array(([0.] * ys.shape[0]))
    # yt_adv = np.array(([1.] * yt.shape[0]))

    # y_advb_1 = np.array(([1] * param["batch_size"] + [0] * param["batch_size"])) # For gradient reversal
    # y_advb_2 = np.array(([0] * param["batch_size"] + [1] * param["batch_size"]))
    # weight_class = np.array(([1] * param["batch_size"] + [0] * param["batch_size"]))
    # weight_adv = np.ones((param["batch_size"] * 2,))
    S_batches = batch_generator([Xs_train, ys_train], param["batch_size"])
    T_batches = batch_generator([Xt_train, np.zeros(shape = (len(Xt_train),))], param["batch_size"])

    param["target_accuracy"] = 0

    optim = {}
    optim["iter"] = 0
    optim["acc"] = ""
    optim["labels"] = np.array(Xt.shape[0],)
    gap_last_snap = 0

    acc_source=[]
    acc_target=[]
    acc_domain_source=[]
    acc_domain_target=[]

    for i in range(param["num_iterations"]):        
        Xsb, ysb = next(S_batches)
        Xtb, ytb = next(T_batches)
        # X_adv = np.concatenate([Xsb, Xtb])
        # y_class = np.concatenate([ysb, np.zeros_like(ysb)])

        # adv_weights = []
        # for layer in models["combined_model"].layers:
        #     if (layer.name.startswith("dis_")):
        #         adv_weights.append(layer.get_weights())
          
        # stats1 = models["combined_model"].train_on_batch(X_adv, [y_class, y_advb_1],\
        #                         sample_weight=[weight_class, weight_adv])            
        # k = 0
        # for layer in models["combined_model"].layers:
        #     if (layer.name.startswith("dis_")):                    
        #         layer.set_weights(adv_weights[k])
        #         k += 1

        # class_weights = []        
        # for layer in models["combined_model"].layers:
        #     if (not layer.name.startswith("dis_")):
        #         class_weights.append(layer.get_weights())  

        stats1 = models["combined_classifier"].train_on_batch(Xsb, [ysb])

        # k = 0
        # for layer in models["combined_model"].layers:
        #     if (not layer.name.startswith("dis_")):
        #         layer.set_weights(class_weights[k])
        #         k += 1

        if ((i + 1) % param["test_interval"] == 0):
            ys_pred = models["combined_classifier"].predict(Xs_train)
            yt_pred = models["combined_classifier"].predict(Xt_train)
            # ys_adv_pred = models["combined_discriminator"].predict(Xs)
            # yt_adv_pred = models["combined_discriminator"].predict(Xt)

            source_accuracy = accuracy_score(ys_train.argmax(1), ys_pred.argmax(1))              
            target_accuracy = accuracy_score(yt_train.argmax(1), yt_pred.argmax(1))
            # source_domain_accuracy = accuracy_score(ys_adv, np.round(ys_adv_pred))              
            # target_domain_accuracy = accuracy_score(yt_adv, np.round(yt_adv_pred))

            acc_source.append(source_accuracy)
            acc_target.append(target_accuracy)
            # acc_domain_source.append(source_domain_accuracy)
            # acc_domain_target.append(target_domain_accuracy)

            log_str = "iter: {:05d}: \nLABEL CLASSIFICATION: source_accuracy: {:.5f}, target_accuracy: {:.5f}"\
                                                         .format(i, source_accuracy*100, target_accuracy*100)
            print(log_str)

            if param["target_accuracy"] < target_accuracy:              
                optim["iter"] = i
                optim["acc"] = log_str
                optim["labels"] = ys_pred.argmax(1)

                # if (gap_last_snap >= param["snapshot_interval"]):
                #     gap_last_snap = 0
                #     np.save(os.path.join(param["output_path"],"yPred_{}".format(optim["iter"])), optim["labels"])
                #     open(os.path.join(param["output_path"], "acc_{}.txt".format(optim["iter"])), "w").write(optim["acc"])
                #     models["combined_classifier"].save(os.path.join(param["output_path"],"iter_{:05d}_model.h5".format(i)))
        gap_last_snap = gap_last_snap + 1;

    print("Source matrix: ",metrics.confusion_matrix(ys_train.argmax(1), ys_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt_train.argmax(1), yt_pred.argmax(1)))

    ys_test_pred = models["combined_classifier"].predict(Xs_test)
    yt_test_pred = models["combined_classifier"].predict(Xt_test)
    source_accuracy_test = accuracy_score(ys_test.argmax(1), ys_test_pred.argmax(1))              
    target_accuracy_test = accuracy_score(yt_test.argmax(1), yt_test_pred.argmax(1))

    print("source accuracy test",source_accuracy_test)
    print("target accuracy test",target_accuracy_test)

    print("Source matrix: ",metrics.confusion_matrix(ys_test.argmax(1), ys_test_pred.argmax(1)))
    print("Target matrix: ",metrics.confusion_matrix(yt_test.argmax(1), yt_test_pred.argmax(1)))

    # ys_test_adv_pred = models["combined_discriminator"].predict(Xs_test)
    # yt_test_adv_pred = models["combined_discriminator"].predict(Xt_test)
    # domain_source_accuracy_test = accuracy_score(ys_adv, np.round(ys_test_adv_pred))              
    # domain_target_accuracy_test = accuracy_score(yt_adv, np.round(yt_test_adv_pred))

    # print("discriminator source accuracy test",domain_source_accuracy_test)
    # print("discriminator target accuracy test",domain_target_accuracy_test)

    # print(param["num_iterations"]/ (param["test_interval"]-1))
    N = np.arange(0,len(acc_source))

    plt.style.use("ggplot")
    plt.figure()
    plt.plot(N, np.array(acc_source), label="Source accuracy")
    plt.plot(N, np.array(acc_target), label="Target accuracy")
    # plt.plot(N, np.array(acc_domain_source), label="Domain Source accuracy")
    # plt.plot(N, np.array(acc_domain_target), label="Domain Target accuracy")
    plt.title("Training Accuracy of Source and Target ")
    plt.xlabel("Number of iteration")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

if __name__ == "__main__":
    # Read parameter values from the console
    parser = argparse.ArgumentParser(description = 'Domain Adaptation')
    parser.add_argument('--number_of_gpus', type = int, nargs = '?', default = '1', help = "Number of gpus to run")
    parser.add_argument('--network_name', type = str, default = 'ResNet50', help = "Name of the feature extractor network")
    parser.add_argument('--dataset_name', type = str, default = 'Office', help = "Name of the source dataset")
    parser.add_argument('--dropout_classifier', type = float, default = 0.25, help = "Dropout ratio for classifier")
    parser.add_argument('--dropout_discriminator', type = float, default = 0.25, help = "Dropout ratio for discriminator")    
    parser.add_argument('--source_path', type = str, default = 'amazon_10_list.txt', help = "Path to source dataset")
    parser.add_argument('--target_path', type = str, default = 'webcam_10_list.txt', help = "Path to target dataset")
    parser.add_argument('--lr_classifier', type = float, default = 0.0001, help = "Learning rate for classifier model")
    parser.add_argument('--b1_classifier', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for classifier model optimizer")
    parser.add_argument('--b2_classifier', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for classifier model optimizer")
    parser.add_argument('--lr_discriminator', type = float, default = 0.00001, help = "Learning rate for discriminator model")
    parser.add_argument('--b1_discriminator', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for discriminator model optimizer")
    parser.add_argument('--b2_discriminator', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for discriminator model optimizer")
    parser.add_argument('--lr_combined', type = float, default = 0.00001, help = "Learning rate for combined model")
    parser.add_argument('--b1_combined', type = float, default = 0.9, help = "Exponential decay rate of first moment \
                                                                                             for combined model optimizer")
    parser.add_argument('--b2_combined', type = float, default = 0.999, help = "Exponential decay rate of second moment \
                                                                                            for combined model optimizer")
    parser.add_argument('--classifier_loss_weight', type = float, default = 1, help = "Classifier loss weight")
    parser.add_argument('--discriminator_loss_weight', type = float, default = 4, help = "Discriminator loss weight")
    parser.add_argument('--batch_size', type = int, default = 32, help = "Batch size for training")
    parser.add_argument('--test_interval', type = int, default = 3, help = "Gap between two successive test phases")
    parser.add_argument('--num_iterations', type = int, default = 120, help = "Number of iterations")
    parser.add_argument('--snapshot_interval', type = int, default = 500, help = "Minimum gap between saving outputs")
    parser.add_argument('--output_dir', type = str, default = 'Models', help = "Directory for saving outputs")
    # args = parser.parse_args()

    # Set GPU device
    # os.environ["CUDA_VISIBLE_DEVICES"] = str(list(np.arange(args.number_of_gpus))).strip('[]')

    # Initialize parameters
    param = {}
    param["number_of_gpus"] = 1
    param["network_name"] = 'ResNet50'
    param["inp_dims"] = [224, 224, 3]
    param["num_iterations"] = 80
    # param["num_iterations"] = 500
    param["lr_classifier"] = 0.0001
    param["b1_classifier"] = 0.9
    param["b2_classifier"] = 0.999    
    param["lr_discriminator"] = 0.00001
    param["b1_discriminator"] =  0.9
    param["b2_discriminator"] = 0.999
    param["lr_combined"] = 0.00001
    param["b1_combined"] =  0.9
    param["b2_combined"] =  0.999       
    # param["batch_size"] = int(32)
    param["batch_size"] = int(32/2)
    param["class_loss_weight"] = 1
    param["dis_loss_weight"] = 4    
    param["drop_classifier"] = 0.25
    param["drop_discriminator"] = 0.25
    param["test_interval"] = 20
    param["source_path"] = 'drive/My Drive/project_data/your_file.txt'
    param["target_path"] = 'drive/My Drive/project_data/your_file_shelly.txt' 
    # param["snapshot_interval"] = 500
    param["snapshot_interval"] = 5
    param["output_path"] = 'drive/My Drive/project_data/result2'

    # Create directory for saving models and log files
    if not os.path.exists(param["output_path"]):
        os.mkdir(param["output_path"])
    
    # Load source and target data
    param["source_data"], param["source_label"] = data_loader(param["source_path"], param["inp_dims"])
    param["target_data"], param["target_label"] = data_loader(param["target_path"], param["inp_dims"])

    # Encode labels into one-hot format
    param["source_label"], param["target_label"] = one_hot_encoding(param)

    # Train data
    train(param)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# iter: 00011:
# LABEL CLASSIFICATION: source_accuracy: 81.11111, target_accuracy: 41.11111
# iter: 00023:
# LABEL CLASSIFICATION: source_accuracy: 92.22222, target_accuracy: 34.44444
# iter: 00035:
# LABEL CLASSIFICATION: source_accuracy: 98.88889, target_accuracy: 36.66667
# iter: 00047:
# LABEL CLASSIFICATION: source_accuracy: 98.88889, target_accuracy: 35.55556
# iter: 00059:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 38.88889
# iter: 00071:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00083:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 40.00000
# iter: 00095:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 38.88889
# iter: 00107:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 42.22222
# iter: 00119:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00131:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00143:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00155:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 37.77778
# iter: 00167:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 35.55556
# iter: 00179:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00191:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 41.11111
# iter: 00203:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 36.66667
# iter: 00215:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 38.88889
# iter: 00227:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 33.33333
# iter: 00239:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 35.55556
# iter: 00251:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 43.33333
# iter: 00263:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 50.00000
# iter: 00275:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 48.88889
# iter: 00287:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 45.55556
# iter: 00299:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 48.88889
# iter: 00311:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 47.77778
# iter: 00323:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 45.55556
# iter: 00335:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 44.44444
# iter: 00347:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 44.44444
# iter: 00359:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 42.22222
# iter: 00371:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 40.00000
# iter: 00383:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 32.22222
# iter: 00395:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 33.33333
# iter: 00407:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00419:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00431:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00443:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00455:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00467:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# iter: 00479:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 30.00000
# iter: 00491:
# LABEL CLASSIFICATION: source_accuracy: 100.00000, target_accuracy: 31.11111
# Source matrix:  [[60  0]
#  [ 0 30]]
# Target matrix:  [[27  1]
#  [61  1]]
# source accuracy test 0.7666666666666667
# target accuracy test 0.36666666666666664
# Source matrix:  [[17  2]
#  [ 5  6]]
# Target matrix:  [[10  0]
#  [19  1]]
